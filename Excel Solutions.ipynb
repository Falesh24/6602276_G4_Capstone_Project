# %% [markdown]
# What is the average selling price of used cars by Brand ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_g = pd.read_csv("used_cars.csv")

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75
# 6015  1120 CC     71 bhp    5.0        NaN   4.00
# 6016  2498 CC    112 bhp    8.0        NaN   2.90
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50
#
# [6019 rows x 14 columns]

# %%
df_g.iloc[0,1].split()[0]
# Out:
# 'Maruti'

# %%
df_g["Name"]
# Out:
# 0                 Maruti Wagon R LXI CNG
# 1       Hyundai Creta 1.6 CRDi SX Option
# 2                           Honda Jazz V
# 3                      Maruti Ertiga VDI
# 4        Audi A4 New 2.0 TDI Multitronic
#                       ...
# 6014                    Maruti Swift VDI
# 6015            Hyundai Xcent 1.1 CRDi S
# 6016               Mahindra Xylo D4 BSIV
# 6017                  Maruti Wagon R VXI
# 6018               Chevrolet Beat Diesel
# Name: Name, Length: 6019, dtype: object

# %%
df_g["Brand"] = df_g["Name"].apply(lambda x:x.split()[0])

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price      Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75     Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50    Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00     Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       Audi
# ...       ...        ...    ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015  1120 CC     71 bhp    5.0        NaN   4.00    Hyundai
# 6016  2498 CC    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
# df_g.groupby("Brand").agg({"Price" : ["mean", "min", "max"]}).reset_index()

# %%
df_g.groupby("Brand").agg({"Price":["mean"]}).reset_index()
# Out:
#             Brand       Price
#                          mean
# 0      Ambassador    1.350000
# 1            Audi   25.537712
# 2             BMW   25.243146
# 3         Bentley   59.000000
# 4       Chevrolet    3.044463
# 5          Datsun    3.049231
# 6            Fiat    3.269286
# 7           Force    9.333333
# 8            Ford    6.889400
# 9           Honda    5.411743
# 10        Hyundai    5.343433
# 11          ISUZU   12.045000
# 12          Isuzu   20.000000
# 13         Jaguar   37.632250
# 14           Jeep   18.718667
# 15    Lamborghini  120.000000
# 16           Land   39.259500
# 17       Mahindra    8.045919
# 18         Maruti    4.517267
# 19  Mercedes-Benz   26.809874
# 20           Mini   26.896923
# 21     Mitsubishi   11.058889
# 22         Nissan    4.738352
# 23        Porsche   48.348333
# 24        Renault    5.799034
# 25          Skoda    7.559075
# 26          Smart    3.000000
# 27           Tata    3.562849
# 28         Toyota   11.580024
# 29     Volkswagen    5.307270
# 30          Volvo   18.802857

# %% [markdown]
# 2. How many cars are available per year ?

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df_g["Year"].value_counts().reset_index(),x="Year",y="count")
plt.title("Cars Available Per Year")
plt.xticks(rotation=45)
plt.show()

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price      Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75     Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50    Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00     Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       Audi
# ...       ...        ...    ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015  1120 CC     71 bhp    5.0        NaN   4.00    Hyundai
# 6016  2498 CC    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %% [markdown]
# 3. What is the average mileage (kmpl/km/kg) by fuel type ?

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 6014              27365    Diesel       Manual      First   28.4 kmpl
# 6015             100000    Diesel       Manual      First   24.4 kmpl
# 6016              55000    Diesel       Manual     Second   14.0 kmpl
# 6017              46000    Petrol       Manual      First   18.9 kmpl
# 6018              47000    Diesel       Manual      First  25.44 kmpl
#
#        Engine      Power  Seats  New_Price  Price      Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75     Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50    Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00     Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       Audi
# ...       ...        ...    ...        ...    ...        ...
# 6014  1248 CC     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015  1120 CC     71 bhp    5.0        NaN   4.00    Hyundai
# 6016  2498 CC    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   998 CC   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   936 CC   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
def clean_mileage(mileage):
    return float(str(mileage).split()[0]) if pd.notna(mileage) else None

# %%
df_g["Mileage"] = df_g["Mileage"].apply(clean_mileage)

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage   Engine  \
# 0                 72000       CNG       Manual      First    26.60   998 CC
# 1                 41000    Diesel       Manual      First    19.67  1582 CC
# 2                 46000    Petrol       Manual      First    18.20  1199 CC
# 3                 87000    Diesel       Manual      First    20.77  1248 CC
# 4                 40670    Diesel    Automatic     Second    15.20  1968 CC
# ...                 ...       ...          ...        ...      ...      ...
# 6014              27365    Diesel       Manual      First    28.40  1248 CC
# 6015             100000    Diesel       Manual      First    24.40  1120 CC
# 6016              55000    Diesel       Manual     Second    14.00  2498 CC
# 6017              46000    Petrol       Manual      First    18.90   998 CC
# 6018              47000    Diesel       Manual      First    25.44   936 CC
#
#           Power  Seats  New_Price  Price      Brand
# 0     58.16 bhp    5.0        NaN   1.75     Maruti
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     88.76 bhp    7.0        NaN   6.00     Maruti
# 4     140.8 bhp    5.0        NaN  17.74       Audi
# ...         ...    ...        ...    ...        ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015     71 bhp    5.0        NaN   4.00    Hyundai
# 6016    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
import plotly.express as px

# %%
fig = px.pie(df_g.groupby("Fuel_Type").agg({"Mileage":"mean"}).reset_index(),names="Fuel_Type",values="Mileage")
fig.show()

# %% [markdown]
# 4. What is the distribution of cars by transmission type ?

# %%
fig = px.pie(df_g["Transmission"].value_counts().reset_index(),names="Transmission",values="count",title="Pie Chart")
fig.show()

# %% [markdown]
# 5. Which Owner type offered the most cars, and what's the average selling price ?

# %%
q = df_g.groupby("Owner_Type").agg({"Name":"count","Price":"mean"}).reset_index()

# %%
fig, ax1 = plt.subplots(figsize=(8,5))

ax1.bar(q["Owner_Type"], q["Name"], color='skyblue',label="Car Count")
ax1.set_ylabel("Car Count", color='black')
ax1.tick_params(axis='y', labelcolor='black')

ax2 = ax1.twinx()
ax2.plot(q["Owner_Type"], q["Price"], color='red', marker='o', label="Avg Price")
ax2.set_ylabel("Average Price",color='red')
ax2.tick_params(axis='y', labelcolor='red')

# %% [markdown]
# 6. Which year has the highest average selling price?

# %%
year_price = df_g.groupby("Year").agg({"Price":"mean"}).reset_index()

# %%
(year_price.sort_values(by="Price",ascending=False)).iloc[0]
# Out:
# Year     2019.000000
# Price      19.464118
# Name: 21, dtype: float64

# %% [markdown]
# 7. What is the relationship between engine size (binned) and price ?

# %%
def clean_Engine(engine):
    return float(str(engine).split()[0]) if pd.notna(engine) else None

# %%
df_g["Engine"] = df_g["Engine"].apply(clean_Engine)

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 72000       CNG       Manual      First    26.60   998.0
# 1                 41000    Diesel       Manual      First    19.67  1582.0
# 2                 46000    Petrol       Manual      First    18.20  1199.0
# 3                 87000    Diesel       Manual      First    20.77  1248.0
# 4                 40670    Diesel    Automatic     Second    15.20  1968.0
# ...                 ...       ...          ...        ...      ...     ...
# 6014              27365    Diesel       Manual      First    28.40  1248.0
# 6015             100000    Diesel       Manual      First    24.40  1120.0
# 6016              55000    Diesel       Manual     Second    14.00  2498.0
# 6017              46000    Petrol       Manual      First    18.90   998.0
# 6018              47000    Diesel       Manual      First    25.44   936.0
#
#           Power  Seats  New_Price  Price      Brand
# 0     58.16 bhp    5.0        NaN   1.75     Maruti
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda
# 3     88.76 bhp    7.0        NaN   6.00     Maruti
# 4     140.8 bhp    5.0        NaN  17.74       Audi
# ...         ...    ...        ...    ...        ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti
# 6015     71 bhp    5.0        NaN   4.00    Hyundai
# 6016    112 bhp    8.0        NaN   2.90   Mahindra
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet
#
# [6019 rows x 15 columns]

# %%
df_g["engine_size_bin"] = pd.cut(df_g["Engine"],bins=[0,1000,2000,3000,4000,5000,6000])

# %%
df_g
# Out:
#       Unnamed: 0                              Name    Location  Year  \
# 0              0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1              1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2              2                      Honda Jazz V     Chennai  2011
# 3              3                 Maruti Ertiga VDI     Chennai  2012
# 4              4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...          ...                               ...         ...   ...
# 6014        6014                  Maruti Swift VDI       Delhi  2014
# 6015        6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016        6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017        6017                Maruti Wagon R VXI     Kolkata  2013
# 6018        6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type  Mileage  Engine  \
# 0                 72000       CNG       Manual      First    26.60   998.0
# 1                 41000    Diesel       Manual      First    19.67  1582.0
# 2                 46000    Petrol       Manual      First    18.20  1199.0
# 3                 87000    Diesel       Manual      First    20.77  1248.0
# 4                 40670    Diesel    Automatic     Second    15.20  1968.0
# ...                 ...       ...          ...        ...      ...     ...
# 6014              27365    Diesel       Manual      First    28.40  1248.0
# 6015             100000    Diesel       Manual      First    24.40  1120.0
# 6016              55000    Diesel       Manual     Second    14.00  2498.0
# 6017              46000    Petrol       Manual      First    18.90   998.0
# 6018              47000    Diesel       Manual      First    25.44   936.0
#
#           Power  Seats  New_Price  Price      Brand engine_size_bin
# 0     58.16 bhp    5.0        NaN   1.75     Maruti       (0, 1000]
# 1     126.2 bhp    5.0        NaN  12.50    Hyundai    (1000, 2000]
# 2      88.7 bhp    5.0  8.61 Lakh   4.50      Honda    (1000, 2000]
# 3     88.76 bhp    7.0        NaN   6.00     Maruti    (1000, 2000]
# 4     140.8 bhp    5.0        NaN  17.74       Audi    (1000, 2000]
# ...         ...    ...        ...    ...        ...             ...
# 6014     74 bhp    5.0  7.88 Lakh   4.75     Maruti    (1000, 2000]
# 6015     71 bhp    5.0        NaN   4.00    Hyundai    (1000, 2000]
# 6016    112 bhp    8.0        NaN   2.90   Mahindra    (2000, 3000]
# 6017   67.1 bhp    5.0        NaN   2.65     Maruti       (0, 1000]
# 6018   57.6 bhp    5.0        NaN   2.50  Chevrolet       (0, 1000]
#
# [6019 rows x 16 columns]

# %%
q2 = df_g.groupby("engine_size_bin").agg({"Price":"mean"}).reset_index()
# Out:
# /var/folders/b1/ztc67q253tsdmqvpl119hnx00000gn/T/ipykernel_33365/2664836751.py:1: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
q2["engine_size_bin"] = q2['engine_size_bin'].astype(str)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=q2,x="engine_size_bin",y="Price")
plt.title("Relationship between engine size and price")
plt.xticks(rotation=45)
plt.show()
